# %% [markdown]
# # 1. Create

# %%
import pandas as pd

# %%
dfcsv = pd.read_csv('../projects/titanic-ml/train.csv')

# %%
dfcsv.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
tempdict = {'col1':[1,2,3], 'col2':[4,5,6], 'col3': [7,8,9]}

# %%
dictdf=pd.DataFrame.from_dict(tempdict)

# %%
dictdf.head()
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9

# %%
df.tail(2)
# Out:
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 889          890         1       1  Behr, Mr. Karl Howell  male  26.0      0
# 890          891         0       3    Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket   Fare Cabin Embarked
# 889      0  111369  30.00  C148        C
# 890      0  370376   7.75   NaN        Q

# %%
data = [
    {"Name": "Alice", "Age": 25, "City": "NYC"},
    {"Name": "Bob",   "Age": 30, "City": "SF"},
    {"Name": "Charlie", "City": "LA"}  # Missing Age — handled as NaN
]

df = pd.DataFrame(data)
print(df)
# Out:
#       Name   Age City
# 0    Alice  25.0  NYC
# 1      Bob  30.0   SF
# 2  Charlie   NaN   LA

# %%
dfcsv.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
dfcsv.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
dfcsv.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
dfcsv.describe(include='object')
# Out:
#                        Name   Sex  Ticket Cabin Embarked
# count                   891   891     891   204      889
# unique                  891     2     681   147        3
# top     Dooley, Mr. Patrick  male  347082    G6        S
# freq                      1   577       7     4      644

# %%
dfcsv['Embarked']
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
dfcsv[['Embarked','Sex']]
# Out:
#     Embarked     Sex
# 0          S    male
# 1          C  female
# 2          S  female
# 3          S  female
# 4          S    male
# ..       ...     ...
# 886        S    male
# 887        S  female
# 888        S  female
# 889        C    male
# 890        Q    male
#
# [891 rows x 2 columns]

# %%
dfcsv.Cabin.unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
dfcsv[dfcsv['Sex']=='female']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
dfcsv[(dfcsv['Sex']=='female') & (dfcsv['Embarked']=='S')]
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 880          881         1       2
# 882          883         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dfcsv.iloc[14]
# Out:
# PassengerId                                      15
# Survived                                          0
# Pclass                                            3
# Name           Vestrom, Miss. Hulda Amanda Adolfina
# Sex                                          female
# Age                                            14.0
# SibSp                                             0
# Parch                                             0
# Ticket                                       350406
# Fare                                         7.8542
# Cabin                                           NaN
# Embarked                                          S
# Name: 14, dtype: object

# %%
dfcsv.iloc[14,0]
# Out:
# np.int64(15)

# %%
dfcsv.iloc[14,-1]
# Out:
# 'S'

# %%
dfcsv.iloc[22:33]
# Out:
#     PassengerId  Survived  Pclass  \
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# 26           27         0       3
# 27           28         0       1
# 28           29         1       3
# 29           30         0       3
# 30           31         0       1
# 31           32         1       1
# 32           33         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 22                        McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
# 24                      Palsson, Miss. Torborg Danira  female   8.0      3
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 26                            Emir, Mr. Farred Chehab    male   NaN      0
# 27                     Fortune, Mr. Charles Alexander    male  19.0      3
# ...

# %%
passenger_id=dfcsv.copy()
passenger_id.set_index('PassengerId', inplace=True)

# %%
passenger_id.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
passenger_id.loc[2]
# Out:
# Survived                                                    1
# Pclass                                                      1
# Name        Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                    female
# Age                                                      38.0
# SibSp                                                       1
# Parch                                                       0
# Ticket                                               PC 17599
# Fare                                                  71.2833
# Cabin                                                     C85
# Embarked                                                    C
# Name: 2, dtype: object

# %% [markdown]
# # 3.Update

# %%
dfcsv.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
dfcsv.dropna(inplace=True)

# %%
dfcsv.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
dfcsv.drop('Parch', axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dfcsv['new column']=dfcsv['Age']+dfcsv['Fare']

# %%
dfcsv.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 3            4         1       1
# 6            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch    Ticket     Fare Cabin Embarked  new column
# 1      0  PC 17599  71.2833   C85        C    109.2833
# 3      0    113803  53.1000  C123        S     88.1000
# 6      0     17463  51.8625   E46        S    105.8625

# %%
dfcsv=dfcsv.drop('new column', axis=1)

# %%
dfcsv.iloc[0,-1]='S'
dfcsv.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch    Ticket     Fare Cabin Embarked
# 1      0  PC 17599  71.2833   C85        S
# 3      0    113803  53.1000  C123        S

# %%
dfcsv['Female']=dfcsv['Sex'].apply(lambda x: 1 if x=='female' else 0)

# %%
dfcsv.head(10)
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
# 21           22         1       2
# 23           24         1       1
# 27           28         0       1
# 52           53         1       1
# 54           55         0       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 21                              Beesley, Mr. Lawrence    male  34.0      0
# ...

# %% [markdown]
# # 4. Update

# %%
dfcsv.to_csv('output.csv')

# %%
dfcsv.to_json()
# Out:
# '{"PassengerId":{"1":2,"3":4,"6":7,"10":11,"11":12,"21":22,"23":24,"27":28,"52":53,"54":55,"62":63,"66":67,"75":76,"88":89,"92":93,"96":97,"97":98,"102":103,"110":111,"118":119,"123":124,"124":125,"136":137,"137":138,"139":140,"148":149,"151":152,"170":171,"174":175,"177":178,"183":184,"193":194,"194":195,"195":196,"205":206,"209":210,"215":216,"218":219,"224":225,"230":231,"245":246,"248":249,"251":252,"252":253,"257":258,"262":263,"263":264,"268":269,"269":270,"273":274,"275":276,"291":292,"292":293,"297":298,"299":300,"305":306,"307":308,"309":310,"310":311,"311":312,"318":319,"319":320,"325":326,"327":328,"329":330,"331":332,"332":333,"336":337,"337":338,"339":340,"340":341,"341":342,"345":346,"356":357,"366":367,"369":370,"370":371,"377":378,"390":391,"393":394,"394":395,"412":413,"429":430,"430":431,"434":435,"435":436,"438":439,"445":446,"449":450,"452":453,"453":454,"456":457,"460":461,"462":463,"473":474,"484":485,"486":487,"487":488,"492":493,"496":497,"498":499,"504":505,"
# ...

# %%
df.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Name</th>\n      <th>Age</th>\n      <th>City</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Alice</td>\n      <td>25.0</td>\n      <td>NYC</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Bob</td>\n      <td>30.0</td>\n      <td>SF</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Charlie</td>\n      <td>NaN</td>\n      <td>LA</td>\n    </tr>\n  </tbody>\n</table>'

# %%
del dfcsv
